# %% [markdown]
# # Challenge — Module 1.2: Clean a Messy Customer Record
#
# **Format:** one problem, one final answer. To reach the expected output you must use **every** string concept from 1.2: concatenation, `len`, repetition, indexing/slicing, `.upper`/`.lower`/`.strip`/`.replace`, `.split`/`.join`, and f-strings — plus the basics from 1.1 (casting, comparison).
#
# **Scenario.** A CRM exports records as one big semicolon-delimited string with inconsistent casing, padding, and a noisy account-id format. You receive one such record and must normalize it into a single clean report line.

# %% [markdown]
# ## The problem
#
# ### Input
#
# ```python
# raw_record = "  Alice Anderson ; ALICE.A@COMPANY.COM ; Account#12345 ; Active ; 199.99 EUR  "
# ```
#
# The fields, in order: full name, email, account id, status, amount + currency.
#
# ### Required transformations
#
# 1. **Trim** the outer whitespace from the whole record.
# 2. **Split** on `;` and strip the spaces around each field.
# 3. **First name only**: keep just the first word of the name, uppercased. Use the full name's `len` to assert it isn't empty (use `assert`).
# 4. **Email**: lowercased. Also extract the **domain** (everything after `@`) — use slicing or `.split`.
# 5. **Account id**: strip the `Account#` prefix using `.replace`. The remaining string is the numeric id (cast to `int`).
# 6. **Active flag**: `True` if status equals `"Active"`, else `False`.
# 7. **Amount**: take only the number part (drop the currency code) and cast to `float`.
# 8. Build a **separator line** of 40 `=` characters using string repetition.
# 9. Produce a single final f-string line in this exact shape:
#
# ```
# ========================================
# ALICE | alice.a@company.com | id=12345 | active=True | amount=199.99 | domain=company.com
# ```
#
# ### Restrictions
#
# Only what 1.1 and 1.2 covered. No `if`/loops/lists-as-data-structure/functions. (`.split` returns a list, but you just index into it — that's fine.)
#
# ### Hints
#
# - Strip the whole string **before** splitting — otherwise the first and last fields keep their padding.
# - `name.split(" ")[0]` gives the first word.
# - `"@"` is a single character — `email.split("@")[1]` gives the domain.
# - The amount field looks like `"199.99 EUR"` — split on space, take index 0, cast.
# - One final `print(f"...")` with `\n` inside if you want it on two lines, or two separate prints. Either is fine.

# %%
raw_record = "  Alice Anderson ; ALICE.A@COMPANY.COM ; Account#12345 ; Active ; 199.99 EUR  "

# your code here — end with the final formatted report
