# %% [markdown]
# # Exercise 8 — Common String Methods
#
# ## Concept
#
# Strings are **immutable** — methods always return a new string, they never modify the original.
#
# ```python
# s = "  Hello, World!  "
# s.strip()           # "Hello, World!"   — remove leading/trailing whitespace
# s.lower()           # "  hello, world!  "
# s.upper()           # "  HELLO, WORLD!  "
# s.replace(",", ";") # "  Hello; World!  "
# s.startswith(" ")   # True
# s.endswith("!  ")   # True
# ```
#
# You can chain methods: `s.strip().lower()`

# %% [markdown]
# ## Task 1 — Normalize incoming data
#
# A name field arrives from an API with inconsistent formatting. Clean it up:
# - Remove surrounding whitespace
# - Convert to title case (first letter of each word capitalized)
#
# Expected: `"  ALICE smith  "` → `"Alice Smith"`
#
# Hint: check if there's a method that does title case directly.

# %%
raw_name = "  ALICE smith  "

# your code here

# %% [markdown]
# ## Task 2 — CSV delimiter replacement
#
# A CSV file uses semicolons as delimiters but the next system expects commas.
#
# Replace all `;` with `,` and print the result.

# %%
row = "101;Alice Smith;34;True"

# your code here

# %% [markdown]
# ## Task 3 — File type check
#
# Your pipeline should only process `.csv` or `.json` files. Given a filename, check if it ends with one of those extensions (case-insensitive — `Sales.CSV` should also be accepted).
#
# Print `True` or `False`.

# %%
filename1 = "sales_2026.CSV"
filename2 = "report.xlsx"

# your code here
