# %% [markdown]
# # Exercise 6 — String Basics
#
# ## Concept
#
# Strings are sequences of characters. A few fundamentals:
#
# ```python
# s = "hello"
# len(s)          # 5  — number of characters
# s + " world"    # "hello world"  — concatenation
# "-" * 10       # "----------"   — repetition
# ```
#
# String concatenation with `+` only works between strings. To mix types, convert first or use an f-string.

# %% [markdown]
# ## Task 1 — Column header separator
#
# When printing reports, a common pattern is to print a title followed by a separator line the same length as the title.
#
# Given `title = "Sales Report 2026"`, print:
# ```
# Sales Report 2026
# -----------------
# ```
# The separator must have exactly the same length as the title — no hardcoding the number.

# %%
title = "Sales Report 2026"

# your code here

# %% [markdown]
# ## Task 2 — Full name from parts
#
# You receive a first name and a last name from separate columns in a CSV.
#
# Build and print a single `full_name` string in the format `"Last, First"`.
# Then print how many characters it has.

# %%
first = "Alice"
last = "Smith"

# your code here

# %% [markdown]
# ## Task 3 — Log line builder
#
# Build a log line in this format: `[INFO] 2026-05-15 :: Pipeline started`
#
# Given the three variables below, produce that exact string using concatenation (no f-strings this time — they come in Exercise 10).

# %%
level = "INFO"
date = "2026-05-15"
message = "Pipeline started"

# your code here
